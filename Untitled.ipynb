# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# absl-py                       2.1.0
# aiohappyeyeballs              2.3.5
# aiohttp                       3.10.3
# aiosignal                     1.3.1
# alabaster                     0.7.16
# anyio                         4.2.0
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-lru                     2.0.4
# atomicwrites                  1.4.0
# attrs                         23.1.0
# autopep8                      2.0.4
# Babel                         2.11.0
# bcrypt                        3.2.0
# beautifulsoup4                4.12.3
# binaryornot                   0.4.4
# black                         24.4.2
# bleach                        4.1.0
# Brotli                        1.0.9
# ...
