# %%
pip install ollama
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ollama

# %%
response = ollama.chat(model='llama3.2', messages=[{'role': 'user', 'content': 'Why is the sky blue?'}])
print(response['message']['content'])
# Out:
# The sky appears blue because of a phenomenon called Rayleigh scattering, named after the British physicist Lord Rayleigh. He discovered that when sunlight passes through the Earth's atmosphere, it encounters tiny molecules of gases such as nitrogen and oxygen.
#
# These molecules are much smaller than the wavelength of light, so they scatter the shorter (blue) wavelengths more than the longer (red) wavelengths. This is known as selective scattering.
#
# As a result, the blue light is scattered in all directions by the tiny molecules, making it visible from any point on Earth. The longer wavelengths of light, such as red and orange, are not scattered as much and continue to travel in a straight line, reaching our eyes without being deflected.
#
# ...

# %%
stream = ollama.chat(model='orca-mini', messages=[{'role': 'user', 'content': 'Why is the sky blue?'}], stream=True)
for chunk in stream:
  print(chunk['message']['content'], end='', flush=True)
# Out:
#  The sky appears blue because of a phenomenon called Rayleigh scattering. When sunlight enters the Earth's atmosphere, it encounters tiny particles such as oxygen and nitrogen molecules. These particles scatter the light in all directions, but they scatter more strongly towards the longer wavelengths of the spectrum, which are the colors that appear blue. The shorter wavelengths are scattered more efficiently, leaving the longer wavelengths to dominate the visible light. So when we see the sky, it appears blue because of this scattering effect.

# %%
ollama.list()
# Out:
# {'models': [{'name': 'llama3.2:latest',
#    'model': 'llama3.2:latest',
#    'modified_at': '2024-10-15T12:17:31.8293589+05:30',
#    'size': 2019393189,
#    'digest': 'a80c4f17acd55265feec403c7aef86be0c25983ab279d83f3bcd3abbcb5b8b72',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '3.2B',
#     'quantization_level': 'Q4_K_M'}},
#   {'name': 'mistral:latest',
#    'model': 'mistral:latest',
#    'modified_at': '2024-09-30T15:48:40.9638769+05:30',
#    'size': 4113301824,
#    'digest': 'f974a74358d62a017b37c6f424fcdf2744ca02926c4f952513ddf474b2fa5091',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '7.2B',
#     'quantization_level': 'Q4_0'}},
#   {'name': 'falcon2:latest',
#    'model': 'falcon2:latest',
#    'modified_at': '2024-09-03T16:41:13.5726621+05:30',
#    'size': 6382548347,
# ...

# %%
print(ollama.show('orca-mini'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(ollama.show('orca-mini').text)
#
# NameError: name 'ollama' is not defined

# %%
ollama.embeddings(model='orca-mini', prompt='The sky is blue because of Rayleigh scattering')
# Out:
# {'embedding': [0.3004419505596161,
#   -0.04618055000901222,
#   0.10317599773406982,
#   2.242197275161743,
#   -1.9965996742248535,
#   -1.4438468217849731,
#   3.325336217880249,
#   2.7705016136169434,
#   0.551743745803833,
#   0.5226115584373474,
#   2.7776401042938232,
#   -0.7093943953514099,
#   0.11297178268432617,
#   1.5154774188995361,
#   -0.750623881816864,
#   -0.4458789527416229,
#   0.5895896553993225,
#   -1.6250498294830322,
#   -0.3643058240413666,
#   3.324068546295166,
#   -1.6133816242218018,
#   -0.8824800252914429,
#   0.7062018513679504,
#   1.6933695077896118,
#   3.209348678588867,
#   1.009648323059082,
#   0.23953169584274292,
#   1.1091225147247314,
#   0.08926097303628922,
#   -3.238852024078369,
#   0.5159989595413208,
#   2.936824083328247,
#   -0.0512302927672863,
#   -1.1662342548370361,
#   1.8207223415374756,
#   -0.6533234715461731,
#   -0.9141620397567749,
#   0.2974177896976471,
#   0.6253488659858704,
#   -0.5363286733627319,
# ...

# %%
from ollama import Client

client = Client(host='http://localhost:11434')
response = client.chat(model='orca-mini', messages=[{'role': 'user', 'content': 'Why is the sky blue?'}])

# %%
import asyncio
from ollama import AsyncClient

async def chat():
  message = {'role': 'user', 'content': 'Why is the sky blue?'}
  response = await AsyncClient().chat(model='llama3.2', messages=[message])

asyncio.run(chat())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[77], line 8
#       5   message = {'role': 'user', 'content': 'Why is the sky blue?'}
#       6   response = await AsyncClient().chat(model='llama3.2', messages=[message])
# ----> 8 asyncio.run(chat())
#
# File ~\anaconda3\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# ...

# %%
import asyncio
from ollama import AsyncClient

async def chat():
  message = {'role': 'user', 'content': 'Why is the sky blue?'}
  async for part in await AsyncClient().chat(model='llama3.2', messages=[message], stream=True):
    print(part['message']['content'], end='', flush=True)

asyncio.run(chat())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[79], line 9
#       6   async for part in await AsyncClient().chat(model='llama3.2', messages=[message], stream=True):
#       7     print(part['message']['content'], end='', flush=True)
# ----> 9 asyncio.run(chat())
#
# File ~\anaconda3\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# ...
